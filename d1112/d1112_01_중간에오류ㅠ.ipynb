# %%
import pandas as pd
df = pd.read_excel('score.xlsx',index_col='지원번호')

# %%
# 함수선언
df['요일'] = 0
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기  요일
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python   0
# 2번    강태원   구로고  184   40   35   50  55  25        Java   0
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript   0
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN   0
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN   0
# 6번    박동현  디지털고  202   80  100   95  85  80           C   0
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON   0
# 8번    승근열  디지털고  190  100   85   90  95  95          C#   0

# %%
# 특정 셀 부분 수정 가능
df.loc['1번','요일'] = 5
df.iloc[1,9] = 2
# 컬럼 전체 수정
df['요일'] = 0
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기  요일
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python   0
# 2번    강태원   구로고  184   40   35   50  55  25        Java   0
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript   0
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN   0
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN   0
# 6번    박동현  디지털고  202   80  100   95  85  80           C   0
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON   0
# 8번    승근열  디지털고  190  100   85   90  95  95          C#   0

# %%
### 랜덤으로 0~6사이의 랜덤숫자를 입력
import random

for i in range(8):
  df.iloc[i,9] = random.randint(0,6)
# df.shape # (8, 10) 8행, 10열
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기  요일
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python   2
# 2번    강태원   구로고  184   40   35   50  55  25        Java   1
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript   1
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN   2
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN   0
# 6번    박동현  디지털고  202   80  100   95  85  80           C   1
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON   1
# 8번    승근열  디지털고  190  100   85   90  95  95          C#   3

# %%
def func(x):
  if x == 0: return '일요일'
  elif x == 1: return '월요일'
  elif x == 2: return '화요일'
  elif x == 3: return '수요일'
  elif x == 4: return '목요일'
  elif x == 5: return '금요일'
  elif x == 6: return '토요일'

# %%
df['요일'] = df['요일'].apply(func)
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기   요일
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python  화요일
# 2번    강태원   구로고  184   40   35   50  55  25        Java  월요일
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript  월요일
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN  화요일
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN  일요일
# 6번    박동현  디지털고  202   80  100   95  85  80           C  월요일
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON  월요일
# 8번    승근열  디지털고  190  100   85   90  95  95          C#  수요일

# %%
## 결과 컬럼 생성
df['결과'] = '불합격'

## 국어점수가 60점 이상이면 '합격'으로 수정
filt = df['국어'] >= 60 
df.loc[filt,'결과'] = '합격'
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기   요일   결과
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python  화요일   합격
# 2번    강태원   구로고  184   40   35   50  55  25        Java  월요일  불합격
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript  월요일   합격
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN  화요일  불합격
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN  일요일  불합격
# 6번    박동현  디지털고  202   80  100   95  85  80           C  월요일   합격
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON  월요일  불합격
# 8번    승근열  디지털고  190  100   85   90  95  95          C#  수요일   합격

# %%
# 학교 + '등학교'
# 키 + 'cm'
# astype() 으로 타입변경 후 문자열 + 문자열
df['키'] = df['키'].astype(str)+'cm'

# %% [markdown]
# * 컬럼이 숫자가 아니면 실행 안됨
# mean(), max(), min(), std()

# %%
df.groupby('학교')['이름'].count()
df.groupby('학교')['이름'].sum()

# %%
df.groupby('학교')['국어'].mean()
df.groupby('학교')['국어'].count()
df.groupby('학교')['국어'].sum()
# Out:
# 학교
# 구로고     265
# 디지털고    235
# Name: 국어, dtype: int64

# %%
df.info()

# %%
df.groupby(['학교','학년'])['국어'].agg(['mean','min','max','sum'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.groupby(['학교','학년'])['국어'].agg(['mean','min','max','sum'])
#
# File c:\Python\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
df['학년'] = [3,3,2,1,1,3,2,2]

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('chipotle.tsv',sep='\t')
df.tail(2)
# Out:
#       order_id  quantity           item_name  \
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df = pd.read_csv('drinks.csv')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
# 모든 술의 총량을 출력
# total_servings 컬럼 구하기: beer+spirit+wine
# 전체 알코올의 도수 확인
df['total_servings'] = df['beer_servings']+df['spirit_servings']+df['wine_servings']
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  total_servings
# 0                             0.0        AS               0
# 1                             4.9        EU             275
# ...

# %%
# 대륙별 total_servings 구하기

# df['continent'].unique() # 'AS', 'EU', 'AF', nan, 'SA', 'OC' -> 대륙 6개
df.groupby('continent')['total_servings'].sum().sort_values() # nan 은 계산 안됨
# Out:
# continent
# OC     2940
# SA     4227
# AS     4706
# AF     4986
# EU    21085
# Name: total_servings, dtype: int64

# %%
# null 에 들어간 값들 찾기
filt = df['continent'].isnull() 
df.loc[filt,'total_servings']
df.loc[filt,'total_servings'].sum()
# Out:
# np.int64(7721)

# %%
# continent: 대륙 NaN 값을 OT로 변경
df['continent'].fillna('OT',inplace=True)

# %%
df.groupby('continent')['total_servings'].sum().sort_values() # 위에서 안됐던거(NaN) 다시 계산
# Out:
# continent
# OC     2940
# SA     4227
# AS     4706
# AF     4986
# OT     7721
# EU    21085
# Name: total_servings, dtype: int64

# %%
df.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent', 'total_servings'],
#       dtype='object')

# %%
# 술 소비량 대비 알콜 비율이 어느정도 되는지 출력
# df.groupby('total_servings')[]
# 알코올 비율을 계산해서 컬럼(alcohol_rate) 추가
df['alcohol_rate'] = df['total_litres_of_pure_alcohol'] / df['total_servings']
# total_litres_of_pure_alcohol(알코올비율)을 total_servings으로 나눈 것
# 술소비량 대비 알콜 비율이 높은 나라별 20개를 출력 (높은순) - head(20)

# 대륙별 알콜비율 계산해서 출력 (평균)
df.groupby('continent')['alcohol_rate'].sum().sort_values(ascending=False)
# Out:
# continent
# AF    2.636258
# EU    0.788717
# AS    0.719797
# OT    0.410644
# OC    0.270327
# SA    0.214415
# Name: alcohol_rate, dtype: float64

# %%
df['alcohol_rate'].fillna(0,inplace=True)
df

# %%
df.info()

# %%
# df.sort_values('alcohol_rate')
df[['country'],['alcohol_rate']].sort_values('alcohol_rate',ascending=False) # 왜 타입에러가 나지...?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Python\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['country'], ['alcohol_rate'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[92], line 2
#       1 # df.sort_values('alcohol_rate')
# ----> 2 df[['country'],['alcohol_rate']].sort_values('alcohol_rate',ascending=False) # 왜 타입에러가 나지...?
#
# File c:\Python\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
# ...

# %%
df[['country'],['alcohol_rate']].max()

# %%
df[['country']]

# %%
# kor 포함되어 있는 나라를 출력
filt = df['country'].str.lower().str.contains('kor')
df[filt][['country','alcohol_rate']]
# Out:
#          country  alcohol_rate
# 46   North Korea           NaN
# 138  South Korea      0.059394
